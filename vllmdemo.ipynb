# %% [markdown]
# <a href="https://colab.research.google.com/github/JithinBV/llmdeployment/blob/main/vllmdemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install vllm
# Out:
# Collecting vllm
#   Using cached vllm-0.1.3.tar.gz (102 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ninja (from vllm)
#   Using cached ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from vllm) (5.9.5)
# Collecting ray>=2.5.1 (from vllm)
#   Downloading ray-2.6.3-cp310-cp310-manylinux2014_x86_64.whl (56.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 MB 10.2 MB/s eta 0:00:00
# Collecting sentencepiece (from vllm)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vllm) (1.23.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from vllm) (2.0.1+cu118)
# Collecting transformers>=4.31.0 (from vllm)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 102.3 MB/s eta 0:00:00
# Collecting xformers>=0.0.19 (from vllm)
#   Downloading xformers-0.0.20-cp310-cp310-manylinux2014_x86_64.whl (109.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 8.5 MB/s eta 0:00:00
# Collecting fastapi (from vllm)
#   Downloading fastapi-0.101.1-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 8.6 MB/s eta 0:00:00
# Collecting uvicorn (from vllm)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.7 MB/s eta 0:00:00
# Collecting pydantic<2 (from vllm)
#   Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 110.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2->vllm) (4.7.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (8.1.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (3.12.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (4.19.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (1.0.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (23.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (1.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (2.31.0)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray>=2.5.1->vllm) (1.57.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->vllm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->vllm) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->vllm) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->vllm) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->vllm) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->vllm) (16.0.6)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers>=4.31.0->vllm)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->vllm) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=4.31.0->vllm)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 71.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers>=4.31.0->vllm)
#   Downloading safetensors-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->vllm) (4.66.1)
# Collecting pyre-extensions==0.0.29 (from xformers>=0.0.19->vllm)
#   Downloading pyre_extensions-0.0.29-py3-none-any.whl (12 kB)
# Collecting typing-inspect (from pyre-extensions==0.0.29->xformers>=0.0.19->vllm)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->vllm)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.1 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn->vllm)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=4.31.0->vllm) (2023.6.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi->vllm) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->vllm) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.5.1->vllm) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.5.1->vllm) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.5.1->vllm) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray>=2.5.1->vllm) (0.9.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.5.1->vllm) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.5.1->vllm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.5.1->vllm) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray>=2.5.1->vllm) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.0->vllm) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi->vllm) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi->vllm) (1.1.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect->pyre-extensions==0.0.29->xformers>=0.0.19->vllm)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: vllm
#   Building wheel for vllm (pyproject.toml) ... done
#   Created wheel for vllm: filename=vllm-0.1.3-cp310-cp310-linux_x86_64.whl size=12859642 sha256=577102edb0189a6736dcf1d888ac2dc0c28bd551bf8d559a573fe79fb752f988
#   Stored in directory: /root/.cache/pip/wheels/d0/bd/3d/439da460dbc7aed87cac228551088620cb00d5414f6f138224
# Successfully built vllm
# Installing collected packages: tokenizers, sentencepiece, safetensors, ninja, pydantic, mypy-extensions, h11, uvicorn, typing-inspect, starlette, huggingface-hub, transformers, pyre-extensions, fastapi, ray, xformers, vllm
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.1.1
#     Uninstalling pydantic-2.1.1:
#       Successfully uninstalled pydantic-2.1.1
# Successfully installed fastapi-0.101.1 h11-0.14.0 huggingface-hub-0.16.4 mypy-extensions-1.0.0 ninja-1.11.1 pydantic-1.10.12 pyre-extensions-0.0.29 ray-2.6.3 safetensors-0.3.2 sentencepiece-0.1.99 starlette-0.27.0 tokenizers-0.13.3 transformers-4.31.0 typing-inspect-0.9.0 uvicorn-0.23.2 vllm-0.1.3 xformers-0.0.20

# %%
from vllm import LLM, SamplingParams

# %%
prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]

# %%
sampling_params = SamplingParams(temperature=0.8, top_p=0.95)

# %%
llm = LLM(model="facebook/opt-125m")

# %%
llm = LLM(model="google/flan-t5-xxl")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# INFO 08-17 09:42:23 llm_engine.py:70] Initializing an LLM engine with config: model='google/flan-t5-xxl', tokenizer='google/flan-t5-xxl', tokenizer_mode=auto, trust_remote_code=False, dtype=torch.float16, use_dummy_weights=False, download_dir=None, use_np_weights=False, tensor_parallel_size=1, seed=0)
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ec30ee6935c4> in <cell line: 1>()
# ----> 1 llm = LLM(model="google/flan-t5-xxl")
#
# /usr/local/lib/python3.10/dist-packages/vllm/entrypoints/llm.py in __init__(self, model, tokenizer, tokenizer_mode, trust_remote_code, tensor_parallel_size, dtype, seed, **kwargs)
#      64             **kwargs,
#      65         )
# ---> 66         self.llm_engine = LLMEngine.from_engine_args(engine_args)
#      67         self.request_counter = Counter()
#      68
#
# /usr/local/lib/python3.10/dist-packages/vllm/engine/llm_engine.py in from_engine_args(cls, engine_args)
#     218             parallel_config)
#     219         # Create the LLM engine.
# --> 220         engine = cls(*engine_configs,
#     221                      distributed_init_method,
#     222                      placement_group,
#
# /usr/local/lib/python3.10/dist-packages/vllm/engine/llm_engine.py in __init__(self, model_config, cache_config, parallel_config, scheduler_config, distributed_init_method, placement_group, log_stats)
#      99             self._init_workers_ray(placement_group)
#     100         else:
# --> 101             self._init_workers(distributed_init_method)
#     102
#     103         # Profile the memory usage and initialize the cache.
#
# /usr/local/lib/python3.10/dist-packages/vllm/engine/llm_engine.py in _init_workers(self, distributed_init_method)
#     131         )
#     132         self.workers.append(worker)
# --> 133         self._run_workers(
#     134             "init_model",
#     135             get_all_outputs=True,
#
# /usr/local/lib/python3.10/dist-packages/vllm/engine/llm_engine.py in _run_workers(self, method, get_all_outputs, *args, **kwargs)
#     468                 executor = getattr(worker, method)
#     469
# --> 470             output = executor(*args, **kwargs)
#     471             all_outputs.append(output)
#     472
#
# /usr/local/lib/python3.10/dist-packages/vllm/worker/worker.py in init_model(self)
#      65         # Initialize the model.
#      66         set_random_seed(self.model_config.seed)
# ---> 67         self.model = get_model(self.model_config)
#      68
#      69     @torch.inference_mode()
#
# /usr/local/lib/python3.10/dist-packages/vllm/model_executor/model_loader.py in get_model(model_config)
#      39
#      40 def get_model(model_config: ModelConfig) -> nn.Module:
# ---> 41     model_class = _get_model_architecture(model_config.hf_config)
#      42     torch.set_default_dtype(model_config.dtype)
#      43
#
# /usr/local/lib/python3.10/dist-packages/vllm/model_executor/model_loader.py in _get_model_architecture(config)
#      33         if arch in _MODEL_REGISTRY:
#      34             return _MODEL_REGISTRY[arch]
# ---> 35     raise ValueError(
#      36         f"Model architectures {architectures} are not supported for now. "
#      37         f"Supported architectures: {list(_MODEL_REGISTRY.keys())}")
#
# ValueError: Model architectures ['T5ForConditionalGeneration'] are not supported for now. Supported architectures: ['BaiChuanForCausalLM', 'BaichuanForCausalLM', 'BloomForCausalLM', 'FalconForCausalLM', 'GPT2LMHeadModel', 'GPTBigCodeForCausalLM', 'GPTJForCausalLM', 'GPTNeoXForCausalLM', 'LlamaForCausalLM', 'LLaMAForCausalLM', 'MPTForCausalLM', 'OPTForCausalLM', 'RWForCausalLM']

# %%
llm = LLM(model="gpt2")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# INFO 08-17 10:03:18 llm_engine.py:70] Initializing an LLM engine with config: model='gpt2', tokenizer='gpt2', tokenizer_mode=auto, trust_remote_code=False, dtype=torch.float16, use_dummy_weights=False, download_dir=None, use_np_weights=False, tensor_parallel_size=1, seed=0)
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]
# INFO 08-17 10:03:36 llm_engine.py:196] # GPU blocks: 22219, # CPU blocks: 7281

# %%
#llm = LLM(model="bigscience/bloom-560m")

# %%
outputs = llm.generate(prompts, sampling_params)
# Out:
# Processed prompts: 100%|██████████| 4/4 [00:00<00:00, 16.31it/s]

# %%
for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    print(f"Prompt: {prompt!r}, Generated text: {generated_text!r}")
# Out:
# Prompt: 'Hello, my name is', Generated text: " Scott, and I'm a baseball fan. I've watched every single game of"
# Prompt: 'The president of the United States is', Generated text: ' willing to go to the war zones to help. The president of the United States'
# Prompt: 'The capital of France is', Generated text: ' already a relatively reliable capital and the city is a favorite place for locals to escape'
# Prompt: 'The future of AI is', Generated text: " uncertain, but from a business perspective, it's not clear how much profit AI"

# %%
# %%writefile requirements.text
# vllm
# Out:
# Writing requirements.text
